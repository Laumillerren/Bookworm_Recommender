# %% [markdown]
# ## Building a Recommendation Engine from our Search Engine base
#
# The Recommendation system base will be used to understand the interactive system we are building for the bookworm system. This file explains the interactions between the recommendations and the books.

# %%
lmiller_liked_books= ["11069349", "13537029", "26827125", "18209268", "18693763"]

# %%
# !head data/book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
#load in by line so you don't use too much memory
csv_book_mapping = {}
with open("data/book_id_map.csv", "r") as f: 
    while True: 
        line = f.readline()
        if not line: 
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
len(csv_book_mapping) #over 2 million mapping
# Out:
# 2360651

# %%
# !wc -l goodreads_interactions.csv #lots of interactions 4GB
# Out:
# wc: goodreads_interactions.csv: open: No such file or directory

# %%
# !ls -lh | grep goodreads_interactions

# %%
# !head goodreads_interactions.csv
# Out:
# head: goodreads_interactions.csv: No such file or directory

# %%
overlap_users = set() #make a set so everything is unique

with open("data/goodreads_interactions.csv", 'r') as f: 
    while True: 
        line = f.readline()
        if not line: 
            break 
        user_id, csv_id, _, rating, _ = line.split(",") # _ for what i dont care about

        if user_id in overlap_users:
            continue
        try: 
            rating = int(rating)
        except ValueError: 
            continue

        book_id = csv_book_mapping[csv_id] #book id to mapping csv id

        if book_id in lmiller_liked_books and rating >=4: 
            overlap_users.add(user_id)

# %%
rec_lines = [] 

with open("data/goodreads_interactions.csv", 'r') as f: 
    while True: 
        line = f.readline()
        if not line: 
            break 
        user_id, csv_id, _, rating, _ = line.split(",") # _ for what i dont care about
        
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

# %%
len(overlap_users) # a lot of overlapping users
# Out:
# 9866

# %%
len(rec_lines) # a lot of books, needs filtering before recommendations
# Out:
# 6836480

# %%
import pandas as pd

recs_df = pd.DataFrame(rec_lines, columns = ["user_id", "book_id", "rating"])
recs_df["book_id"] = recs_df["book_id"].astype(str)

# %%
recs_df
# Out:
#         user_id   book_id rating
# 0             4    250729      3
# 1             4     32071      3
# 2             4     50833      5
# 3             4     13496      4
# 4             4  13284283      4
# ...         ...       ...    ...
# 6836475  875922   1211950      3
# 6836476  875922      3273      3
# 6836477  875922  19486412      5
# 6836478  875922   1466455      0
# 6836479  875922  28965131      0
#
# [6836480 rows x 3 columns]

# %%
top_recs = recs_df["book_id"].value_counts().head(10)
top_recs = top_recs.index.values

# %%
top_recs
# Out:
# array(['18693763', '22557272', '18143977', '2767052', '11870085', '2657',
#        '4671', '3', '19063', '77203'], dtype=object)

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287140  Runic Astrology: Starcraft and Timekeeping in ...       15
# 3   287141                      The Aeneid for Boys and Girls       46
# 4   378460                              The Wanting of Levine       12
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287140.Run...
# 3  https://www.goodreads.com/book/show/287141.The...
# 4  https://www.goodreads.com/book/show/378460.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://images.gr-assets.com/books/1413219371m...
# 3  https://s.gr-assets.com/assets/nophoto/book/11...
# 4  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                       modified_title
# 0     the unschooled wizard sun wolf and starhawk 12
# 1                               best friends forever
# 2  runic astrology starcraft and timekeeping in t...
# 3                      the aeneid for boys and girls
# 4                              the wanting of levine

# %%
#find book titles where bookid is in top recs
books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
#           book_id                                              title  ratings  \
# 60363       77203                                    The Kite Runner  1848782
# 325058    2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 426763      19063                                     The Book Thief  1193697
# 530012       4671                                   The Great Gatsby  2758812
# 757036   18693763                        Everything I Never Told You   115500
# 904234       2657                              To Kill a Mockingbird  3255518
# 1004013  18143977                        All the Light We Cannot See   498685
# 1004474         3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 1247951  22557272                              The Girl on the Train  1076144
# 1252139  11870085                             The Fault in Our Stars  2429317
#
#                                                        url  \
# 60363    https://www.goodreads.com/book/show/77203.The_...
# 325058   https://www.goodreads.com/book/show/2767052-th...
# 426763   https://www.goodreads.com/book/show/19063.The_...
# 530012   https://www.goodreads.com/book/show/4671.The_G...
# 757036   https://www.goodreads.com/book/show/18693763-e...
# 904234   https://www.goodreads.com/book/show/2657.To_Ki...
# 1004013  https://www.goodreads.com/book/show/18143977-a...
# 1004474  https://www.goodreads.com/book/show/3.Harry_Po...
# 1247951  https://www.goodreads.com/book/show/22557272-t...
# 1252139  https://www.goodreads.com/book/show/11870085-t...
#
#                                                cover_image  \
# 60363    https://images.gr-assets.com/books/1484565687m...
# 325058   https://images.gr-assets.com/books/1447303603m...
# 426763   https://images.gr-assets.com/books/1390053681m...
# 530012   https://images.gr-assets.com/books/1490528560m...
# 757036   https://images.gr-assets.com/books/1386795198m...
# 904234   https://images.gr-assets.com/books/1361975680m...
# 1004013  https://images.gr-assets.com/books/1451445646m...
# 1004474  https://images.gr-assets.com/books/1474154022m...
# 1247951  https://images.gr-assets.com/books/1490903702m...
# 1252139  https://images.gr-assets.com/books/1360206420m...
#
#                                             modified_title
# 60363                                      the kite runner
# 325058                 the hunger games the hunger games 1
# 426763                                      the book thief
# 530012                                    the great gatsby
# 757036                         everything i never told you
# 904234                               to kill a mockingbird
# 1004013                        all the light we cannot see
# 1004474  harry potter and the sorcerers stone harry pot...
# 1247951                              the girl on the train
# 1252139                             the fault in our stars

# %% [markdown]
# This is a very generic list, we want to see what top book from similar readers are rather than top books overall.

# %%
all_recs = recs_df["book_id"].value_counts()

# %%
all_recs
# Out:
# 18693763    8918
# 22557272    6673
# 18143977    6357
# 2767052     6279
# 11870085    6030
#             ...
# 1235617        1
# 18774905       1
# 910381         1
# 1202527        1
# 17554307       1
# Name: book_id, Length: 622617, dtype: int64

# %%
all_recs = all_recs.to_frame().reset_index()

# %%
all_recs
# Out:
#            index  book_id
# 0       18693763     8918
# 1       22557272     6673
# 2       18143977     6357
# 3        2767052     6279
# 4       11870085     6030
# ...          ...      ...
# 622612   1235617        1
# 622613  18774905        1
# 622614    910381        1
# 622615   1202527        1
# 622616  17554307        1
#
# [622617 rows x 2 columns]

# %%
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs
# Out:
#          book_id  book_count
# 0       18693763        8918
# 1       22557272        6673
# 2       18143977        6357
# 3        2767052        6279
# 4       11870085        6030
# ...          ...         ...
# 622612   1235617           1
# 622613  18774905           1
# 622614    910381           1
# 622615   1202527           1
# 622616  17554307           1
#
# [622617 rows x 2 columns]

# %%
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
all_rec

#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1386795198m...
# 13354  https://s.gr-assets.com/assets/nophoto/book/11...
# 8054   https://s.gr-assets.com/assets/nophoto/book/11...
# 4499   https://s.gr-assets.com/assets/nophoto/book/11...
# 102    https://images.gr-assets.com/books/1490351351m...
# 6267   https://images.gr-assets.com/books/1501852384m...
# 6196   https://images.gr-assets.com/books/1501704611m...
# 15370  https://s.gr-assets.com/assets/nophoto/book/11...
# 16237  https://images.gr-assets.com/books/1507936746m...
# 567    https://images.gr-assets.com/books/1499340866m...
#
#                         modified_title       score
# 0          everything i never told you  688.577697
# 13354         ninth house alex stern 1  511.363636
# 8054               vengeful villains 2  432.257143
# 4499    lethal white cormoran strike 4  428.009434
# 102            little fires everywhere  372.009274
# 6267                   the great alone  352.128571
# 6196     obsidio the illuminae files 3  304.439024
# 15370                  the iron season  292.571429
# 16237  my plain jane the lady janies 2  286.230769
# 567                 sing unburied sing  280.536803

# %%
popular_recs = all_recs = all_recs[all_recs["book_count"] > 75].sort_values("score", ascending=False)

# %%
def make_clickable(val): 
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val): 
    return '<img src="{}" width=50></img>'.format(val)

popular_recs[~popular_recs["book_id"].isin(lmiller_liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_85969">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85969_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_85969_level0_col1" class="col_heading level0 col1" >book_count</th>
#       <th id="T_85969_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_85969_level0_col3" class="col_heading level0 col3" >ratings</th>
#       <th id="T_85969_level0_col4" class="col_heading level0 col4" >url</th>
#       <th id="T_85969_level0_col5" class="col_heading level0 col5" >cover_image</th>
#       <th id="T_85969_level0_col6" class="col_heading level0 col6" >modified_title</th>
#       <th id="T_85969_level0_col7" class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85969_level0_row0" class="row_heading level0 row0" >8054</th>
#       <td id="T_85969_row0_col0" class="data row0 col0" >26856502</td>
#       <td id="T_85969_row0_col1" class="data row0 col1" >123</td>
#       <td id="T_85969_row0_col2" class="data row0 col2" >Vengeful (Villains, #2)</td>
#       <td id="T_85969_row0_col3" class="data row0 col3" >35</td>
#       <td id="T_85969_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/26856502-vengeful">Goodreads</a></td>
#       <td id="T_85969_row0_col5" class="data row0 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_85969_row0_col6" class="data row0 col6" >vengeful villains 2</td>
#       <td id="T_85969_row0_col7" class="data row0 col7" >432.257143</td>
#     </tr>
#     <tr>
#       <th id="T_85969_level0_row1" class="row_heading level0 row1" >4499</th>
#       <td id="T_85969_row1_col0" class="data row1 col0" >28170940</td>
#       <td id="T_85969_row1_col1" class="data row1 col1" >213</td>
#       <td id="T_85969_row1_col2" class="data row1 col2" >Lethal White (Cormoran Strike, #4)</td>
#       <td id="T_85969_row1_col3" class="data row1 col3" >106</td>
#       <td id="T_85969_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/28170940-lethal-white">Goodreads</a></td>
#       <td id="T_85969_row1_col5" class="data row1 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_85969_row1_col6" class="data row1 col6" >lethal white cormoran strike 4</td>
#       <td id="T_85969_row1_col7" class="data row1 col7" >428.009434</td>
#     </tr>
#     <tr>
#       <th id="T_85969_level0_row2" class="row_heading level0 row2" >102</th>
#       <td id="T_85969_row2_col0" class="data row2 col0" >34273236</td>
#       <td id="T_85969_row2_col1" class="data row2 col1" >2804</td>
#       <td id="T_85969_row2_col2" class="data row2 col2" >Little Fires Everywhere</td>
#       <td id="T_85969_row2_col3" class="data row2 col3" >21135</td>
#       <td id="T_85969_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/34273236-little-fires-everywhere">Goodreads</a></td>
#       <td id="T_85969_row2_col5" class="data row2 col5" ><img src="https://images.gr-assets.com/books/
row7_col5" class="data row7 col5" ><img src="https://images.gr-assets.com/books/1433828491m/24493732.jpg" width=50></img></td>
#       <td id="T_85969_row7_col6" class="data row7 col6" >solutions and other problems</td>
#       <td id="T_85969_row7_col7" class="data row7 col7" >264.098802</td>
#     </tr>
#     <tr>
#       <th id="T_85969_level0_row8" class="row_heading level0 row8" >525</th>
#       <td id="T_85969_row8_col0" class="data row8 col0" >25810500</td>
#       <td id="T_85969_row8_col1" class="data row8 col1" >1192</td>
#       <td id

# %% [markdown]
# ## Build this Recommendation Engine into a Function
#
# Taking each part of the recommendation system and making it into a function so we can integrate it into a widget format for search queries later on. This will be integrated with our search function as well.

# %%
import pandas as pd

def recommend_books(liked_books, csv_book_mapping_path, interactions_path, books_titles_path):
    """
    Recommend books based on user interactions and a list of liked books.

    Parameters:
    - liked_books (list of str): List of book IDs the user likes.
    - csv_book_mapping_path (str): Path to the book ID mapping CSV file.
    - interactions_path (str): Path to the Goodreads interactions CSV file.
    - books_titles_path (str): Path to the books titles JSON file.

    Returns:
    - pd.DataFrame: Top recommended books with scores, links, and images.
    """
    #book ID mapping
    csv_book_mapping = {}
    with open(csv_book_mapping_path, "r") as f:
        for line in f:
            csv_id, book_id = line.strip().split(",")
            csv_book_mapping[csv_id] = book_id

    #overlap users who rated liked books highly
    overlap_users = set()
    with open(interactions_path, 'r') as f:
        for line in f:
            user_id, csv_id, _, rating, _ = line.split(",")
            try:
                rating = int(rating)
            except ValueError:
                continue

            book_id = csv_book_mapping.get(csv_id)
            if book_id in liked_books and rating >= 4:
                overlap_users.add(user_id)

    #recommendations based on overlap users
    rec_lines = []
    with open(interactions_path, 'r') as f:
        for line in f:
            user_id, csv_id, _, rating, _ = line.split(",")
            if user_id in overlap_users:
                book_id = csv_book_mapping.get(csv_id)
                rec_lines.append([user_id, book_id, int(rating)])

    #DataFrame for recommendations
    recs_df = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
    recs_df["book_id"] = recs_df["book_id"].astype(str)

    #calculate top recommendations
    top_recs = recs_df["book_id"].value_counts()
    books_titles = pd.read_json(books_titles_path)
    books_titles["book_id"] = books_titles["book_id"].astype(str)
    all_recs = top_recs.to_frame().reset_index()
    all_recs.columns = ["book_id", "book_count"]

    #book details
    all_recs = all_recs.merge(books_titles, how="inner", on="book_id")
    all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])

    #recommendations
    popular_recs = all_recs[all_recs["book_count"] > 75].sort_values("score", ascending=False)

    #books already liked by the user
    popular_recs = popular_recs[~popular_recs["book_id"].isin(liked_books)]

    #links and images for better presentation
    def make_clickable(val):
        return f'<a target="_blank" href="{val}">Goodreads</a>'

    def show_image(val):
        return f'<img src="{val}" width=50></img>'

    return popular_recs.head(10).style.format({'url': make_clickable, 'cover_image': show_image})

# %% [markdown]
# ## Using our Recommendation Engine:
#
# The book recommendation system uses a list of bookids. An actual recomendation system would take a book name, convert it to a book id, then provide recomendations.

# %%
liked_books = ["11069349", "13537029", "26827125", "18209268", "18693763"]
recommend_books(
    liked_books, 
    "data/book_id_map.csv", 
    "data/goodreads_interactions.csv", 
    "books_titles.json")
# Out:
# <style type="text/css">
# </style>
# <table id="T_90af5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_
row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/24909347-obsidio">Goodreads</a></td>
#       <td id="T_90af5_row4_col5" class="data row4 col5" ><img src="https://images.gr-assets.com/books/1501704611m/24909347.jpg" width=50></img></td>
#       <td id="T_90af5_row4_col6" class="data row4 col6" >obsidio the illuminae files 3</td>
#       <td id="T_90af5_row4_col7" class="data row4 col7" >304.439024</td>
#     </tr>
#     <tr>
#       <th id="T_90af5_level0_row5" class="row_heading level0 row5" >567</th>
#       <td id="T_90af5_row5_col0" class="data row5 col0" >32920226</td>
#       <td id="T_90af5_row5_col1" class="data row5 col1" >1135</td>
#       <td id="T_90af5_row5_col2" class="data row5 col2" >Sing, Unburied, Sing</td>
#       <td id="T_90af5_row5_col3" class="data row5 col3" >4592</td>
#       <td id="T_90af5_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/32920226-sing-unburied-sing">Goodreads</a></td>
#       <td id="T_90af5_row5_col5" class="data row5 col5" ><img src="https://images.gr-assets.com/books/1499340866m/32920226.jpg" width=50></img></td>
#       <td id="T_90af5_row5_col6" class="data row5 col6" >sing unburied sing</td>
#       <td id="T_90af5_row5_col7" class="data row5 col7" >280.536803</td>
#     </tr>
#     <tr>
#       <th id="T_90af5_level0_row6" class="row_heading level0 row6" >3550</th>
#       <td id="T_90af5_row6_col0" class="data row6 col0" >34217599</td>
#       <td id="T_90af5_row6_col1" class="data row6 col1" >267</td>
#       <td id="T_90af5_row6_col2" class="data row6 col2" >Future Home of the Living God</td>
#       <td id="T_90af5_row6_col3" class="data row6 col3" >263</td>
#       <td id="T_90af5_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/34217599-future-home-of-the-living-god">Goodreads</a></td>
#       <td id="T_90af5_row6_col5" class="data row6 col5" ><img src="https://images.gr-assets.com/books/1499188017m/34217599.jpg" width=50></img></td>
#       <td id="T_90af5_row6_col6" class="data row6 col6" >future home of the living god</td>
#       <td id="T_90af5_row6_col7" class="data row6 col7" >271.060837</td>
#     </tr>
#     <tr>
#       <th id="T_90af5_level0_row7" class="row_heading level0 row7" >3194</th>
#       <td id="T_90af5_row7_col0" class="data row7 col0" >24493732</td>
#       <td id="T_90af5_row7_col1" class="data row7 col1" >297</td>
#       <td id="T_90af5_row7_col2" class="data row7 col2" >Solutions and Other Problems</td>
#       <td id="T_90af5_row7_col3" class="data row7 col3" >334</td>
#       <td id="T_90af5_row7_col4" class="data row7 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/24493732-solutions-and-other-problems">Goodreads</a></td>
#       <td id="T_90af5_row7_col5" class="data row7 col5" ><img src="https://images.gr-assets.com/books/1433828491m/24493732.jpg" width=50></img></td>
#       <td id="T_90af5_row7_col6" class="data row7 col6" >solutions and other problems</td>
#       <td id="T_90af5_row7_col7" class="data row7 col7" >264.098802</td>
#     </tr>
#     <tr>
#       <th id="T_90af5_level0_row8" class="row_heading level0 row8" >525</th>
#       <td id="T_90af5_row8_col0" class="data row8 col0" >25810500</td>
#       <td id="T_90af5_row8_col1" class="data row8 col1" >1192</td>
#       <td id

# %%
book_ids = ["11069349", "13537029", "26827125", "18209268", "18693763"]

# Load the titles from JSON
titles = pd.read_json("books_titles.json")

# Filter the titles DataFrame for the given book IDs
matched_books = titles[titles["book_id"].isin(book_ids)]

# Display the results
print(matched_books[["book_id", "title"]])
# Out:
# Empty DataFrame
# Columns: [book_id, title]
# Index: []

# %%
titles[titles["book_id"] == "13537029"]
# Out:
# Empty DataFrame
# Columns: [book_id, title, ratings, url, cover_image, modified_title]
# Index: []
