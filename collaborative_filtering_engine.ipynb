# %% [markdown]
# # Collaborative Filtering
#
# Using goodreads book list exported from my personal goodreads account. (goodread_library_export)

# %%
import pandas as pd
#only care about Book_Id, User_Id, and My_Rating
#goodreads_library_export is my export of data
my_books = pd.read_csv("data/goodreads_library_export.csv", skiprows = 1)

#filter for only Exclusive Shelf == read
my_books.columns = my_books.columns.str.replace(' ', '_')
my_books = my_books[my_books['Exclusive_Shelf'] == 'read']
my_books['Book_Id'] = my_books['Book_Id'].astype(str)

my_books
# Out:
#       Book_Id  User_Id                                              Title  \
# 0     7896527       -1              Throne of Glass (Throne of Glass, #1)
# 1    35504431       -1                           Turtles All the Way Down
# 2    18774964       -1                                   A Man Called Ove
# 3    50659467       -1  A Court of Thorns and Roses (A Court of Thorns...
# 4    17788401       -1                                          Ugly Love
# ..        ...      ...                                                ...
# 206  39122774       -1  Children of Virtue and Vengeance (Legacy of Or...
# 224  40597810       -1                              Daisy Jones & The Six
# 234  34313931       -1                                  A Woman Is No Man
# 236  32051912       -1                                  The Alice Network
# 237  15796700       -1                                         Americanah
#
#                        Author                 Author_l-f Additional_Authors  \
# 0               Sarah J. Maas             Maas, Sarah J.                NaN
# 1                  John Green                Green, John                NaN
# 2             Fredrik Backman           Backman, Fredrik       Henning Koch
# 3               Sarah J. Maas             Maas, Sarah J.                NaN
# 4              Colleen Hoover            Hoover, Colleen                NaN
# ..                        ...                        ...                ...
# 206              Tomi Adeyemi              Adeyemi, Tomi                NaN
# 224       Taylor Jenkins Reid       Reid, Taylor Jenkins                NaN
# 234                  Etaf Rum                  Rum, Etaf                NaN
# 236                Kate Quinn                Quinn, Kate                NaN
# 237  Chimamanda Ngozi Adichie  Adichie, Chimamanda Ngozi        Jashar Awan
#
#            ISBN        ISBN13  My_Rating  Average_Rating  ...   Date_Read  \
# 0           NaN           NaN          4            4.18  ...         NaN
# 1    0525555366  9.780526e+12          4            3.88  ...         NaN
# 2    1476738017  9.781477e+12          3            4.38  ...         NaN
# 3    1635575567  9.781636e+12          4            4.18  ...         NaN
# 4           NaN           NaN          3            4.03  ...         NaN
# ..          ...           ...        ...             ...  ...         ...
# 206  1250170990  9.781250e+12          5            3.89  ...  2021/01/11
# 224  1524798622  9.781525e+12          5            4.20  ...  2020/07/13
# 234  0062699768  9.780063e+12          5            4.26  ...  2020/06/24
# 236         NaN           NaN          5            4.32  ...  2020/05/01
# 237         NaN           NaN          5            4.32  ...  2020/01/01
#
#      Date_Added  Bookshelves  Bookshelves_with_positions  Exclusive_Shelf  \
# 0    2022/09/08          NaN                         NaN             read
# 1    2022/07/18          NaN                         NaN             read
# 2    2019/10/16          NaN                         NaN             read
# 3    2022/08/12          NaN                         NaN             read
# 4    2022/07/22          NaN                         NaN             read
# ..          ...          ...                         ...              ...
# 206  2020/12/22          NaN                         NaN             read
# 224  2020/07/07          NaN                         NaN             read
# 234  2020/06/21          NaN                         NaN             read
# 236  2020/05/29          NaN                         NaN             read
# 237  2020/05/18          NaN                         NaN             read
#
#     My_Review Spoiler Private_Notes Read_Count Owned_Copies
# 0         NaN     NaN           NaN          1            0
# 1         NaN     NaN           NaN          1            0
# 2         NaN     NaN           NaN          1            0
# 3         NaN     NaN           NaN          1            0
# 4         NaN     NaN           NaN          1            0
# ..        ...     ...           ...        ...          ...
# 206       NaN     NaN           NaN          1            0
# 224       NaN     NaN           NaN          1            0
# 234       NaN     NaN           NaN          1            0
# 236       NaN     NaN           NaN          1            0
# 237       NaN     NaN           NaN          1            0
#
# [136 rows x 25 columns]

# %% [markdown]
# Load the mapping file to be able to link data together

# %%
#load in mapping file to link data
csv_book_mapping = {}

with open("data/book_id_map.csv", "r") as f:
    while True: 
        line = f.readline()
        if not line: 
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %% [markdown]
# Make a set of my_books so if there are any duplicates, they are handled

# %%
#set of books with all unique books we have read
#if you have duplicates, this would get rid of them
book_set = set(my_books["Book_Id"])

# %%
#looking at users that overlap with our books, 
#keys are user_ids and values are num of times user has read a book that we have in our list too

overlap_users = {}

with open("data/goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        book_id = csv_book_mapping.get(csv_id)
        
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 532737

# %% [markdown]
# Filtering for people we have books in common with from the goodreads interaction data

# %%
#filter for people who have at least 20% books in common with us
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/6])

# %%
len(filtered_overlap_users)
# Out:
# 384

# %%
#add the filtered overlap users interactions into a list to look at
interactions_list = []

with open("data/goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

# %%
len(interactions_list)
# Out:
# 3209729

# %%
interactions_list[0] #user_id, book_id, rating
# Out:
# ['520', '13609836', '2']

# %%
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])
interactions
# Out:
#         user_id   book_id rating
# 0           520  13609836      2
# 1           520  11521040      5
# 2           520    301082      4
# 3           520     19501      0
# 4           520   7654769      4
# ...         ...       ...    ...
# 3209724  442043  31931941      0
# 3209725  442043  34130000      0
# 3209726  442043  25387393      0
# 3209727  442043  30237404      0
# 3209728  442043     32095      0
#
# [3209729 rows x 3 columns]

# %%
#add my ratings to interactions df 
# rename Book_Id, User_Id, and My_Rating to match interactions col names
my_books = my_books.rename(columns={
    "User_Id": "user_id",
    "Book_Id": "book_id",
    "My_Rating": "rating"
})

interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])
interactions
# Out:
#         user_id   book_id rating
# 0            -1   7896527      4
# 1            -1  35504431      4
# 2            -1  18774964      3
# 3            -1  50659467      4
# 4            -1  17788401      3
# ...         ...       ...    ...
# 3209724  442043  31931941      0
# 3209725  442043  34130000      0
# 3209726  442043  25387393      0
# 3209727  442043  30237404      0
# 3209728  442043     32095      0
#
# [3209865 rows x 3 columns]

# %%
#make sure everything is in correct form
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
#build a collaborative filtering matrix
#row is different user
#col is different book
#cell is rating

# %%
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes

# %%
len(interactions["user_index"].unique())
# Out:
# 385

# %%
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
len(interactions["book_index"].unique())
# Out:
# 600077

# %%
#sparse matrix
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
ratings_mat_coo
# Out:
# <385x600077 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3209865 stored elements in COOrdinate format>

# %%
ratings_mat_coo.shape
# Out:
# (385, 600077)

# %%
ratings_mat = ratings_mat_coo.tocsr()

# %%
interactions[interactions["user_id"] == "-1"]
# Out:
#     user_id   book_id  rating  user_index  book_index
# 0        -1   7896527       4           0      552790
# 1        -1  35504431       4           0      446534
# 2        -1  18774964       3           0      196321
# 3        -1  50659467       4           0      478789
# 4        -1  17788401       3           0      157692
# ..      ...       ...     ...         ...         ...
# 206      -1  39122774       5           0      457699
# 224      -1  40597810       5           0      460820
# 234      -1  34313931       5           0      435884
# 236      -1  32051912       5           0      414040
# 237      -1  15796700       5           0      107242
#
# [136 rows x 5 columns]

# %%
my_index = 0

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
similarity[2]
# Out:
# 0.006187881761852927

# %%
#take the top 15 users who are similar
import numpy as np
indices = np.argpartition(similarity, -15)[-15:]

# %%
indices
# Out:
# array([ 52, 293, 286, 214, 341,  39,  73,  90,  44, 124, 257, 369, 189,
#        281,   0])

# %%
similar_users = interactions[interactions["user_index"].isin(indices)].copy()

# %%
len(similar_users)
# Out:
# 24499

# %%
similar_users = similar_users[similar_users["user_id"]!="-1"]

# %%
len(similar_users)
# Out:
# 24363

# %%
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])

# %%
book_recs
# Out:
#           count      mean
# book_id
# 1            11  4.090909
# 10000191      1  0.000000
# 10000600      1  0.000000
# 100020        1  0.000000
# 1000751       1  0.000000
# ...         ...       ...
# 99894         1  0.000000
# 99944         1  5.000000
# 9996645       2  0.000000
# 9998          1  0.000000
# 9999107       2  2.000000
#
# [14896 rows x 2 columns]

# %%
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 340648    56471     10210       5         341        3869
# 340649    56471     43641       4         341      466454
# 340650    56471     17245       4         341      139905
# 340651    56471    128029       5         341       53566
# 340652    56471      1934       0         341      207347
# ...         ...       ...     ...         ...         ...
# 2970845  402650  25852735       3         293      332369
# 2970846  402650  35035160       0         293      442636
# 2970847  402650     72854       0         293      537923
# 2970848  402650  33641244       0         293      429502
# 2970849  402650  34017047       0         293      432938
#
# [24363 rows x 5 columns]

# %%
books_titles = pd.read_json("data/books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#         book_id  count      mean  \
# 0             1     11  4.090909
# 1      10000191      1  0.000000
# 2      10000600      1  0.000000
# 3        100020      1  0.000000
# 4       1000751      1  0.000000
# ...         ...    ...       ...
# 14794     99894      1  0.000000
# 14795     99944      1  5.000000
# 14796   9996645      2  0.000000
# 14797      9998      1  0.000000
# 14798   9999107      2  2.000000
#
#                                                    title  ratings  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1                                          Yellow Crocus    17787
# 2                       Old Habits (Wicked Lovely, #2.6)     1628
# 3           Philosophy of Law: A Very Short Introduction      187
# 4                              Pollyanna (Pollyanna, #1)    58040
# ...                                                  ...      ...
# 14794                               The Boys from Brazil    25833
# 14795                                  The Bhagavad Gita    33855
# 14796                               Truly, Madly, Deeply     1268
# 14797                             The Woman in the Dunes    11841
# 14798                               The American Heiress    24522
#
#                                                      url  \
# 0      https://www.goodreads.com/book/show/1.Harry_Po...
# 1      https://www.goodreads.com/book/show/10000191-y...
# 2      https://www.goodreads.com/book/show/10000600-o...
# 3      https://www.goodreads.com/book/show/100020.Phi...
# 4      https://www.goodreads.com/book/show/1000751.Po...
# ...                                                  ...
# 14794  https://www.goodreads.com/book/show/99894.The_...
# 14795  https://www.goodreads.com/book/show/99944.The_...
# 14796  https://www.goodreads.com/book/show/9996645-tr...
# 14797  https://www.goodreads.com/book/show/9998.The_W...
# 14798  https://www.goodreads.com/book/show/9999107-th...
#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1361039191m...
# 1      https://s.gr-assets.com/assets/nophoto/book/11...
# 2      https://images.gr-assets.com/books/1327881013m...
# 3      https://s.gr-assets.com/assets/nophoto/book/11...
# 4      https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                  ...
# 14794  https://images.gr-assets.com/books/1328882615m...
# 14795  https://images.gr-assets.com/books/1383059639m...
# 14796  https://images.gr-assets.com/books/1293090850m...
# 14797  https://images.gr-assets.com/books/1361254930m...
# 14798  https://images.gr-assets.com/books/1307342832m...
#
#                                           modified_title
# 0      harry potter and the halfblood prince harry po...
# 1                                          yellow crocus
# 2                            old habits wicked lovely 26
# 3            philosophy of law a very short introduction
# 4                                  pollyanna pollyanna 1
# ...                                                  ...
# 14794                               the boys from brazil
# 14795                                  the bhagavad gita
# 14796                                 truly madly deeply
# 14797                             the woman in the dunes
# 14798                               the american heiress
#
# [14799 rows x 8 columns]

# %%
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"])

# %%
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"]

# %%
#take out books we have read
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

# %%
book_recs
# Out:
#         book_id  count      mean  \
# 0             1     11  4.090909
# 1      10000191      1  0.000000
# 2      10000600      1  0.000000
# 3        100020      1  0.000000
# 4       1000751      1  0.000000
# ...         ...    ...       ...
# 14794     99894      1  0.000000
# 14795     99944      1  5.000000
# 14796   9996645      2  0.000000
# 14797      9998      1  0.000000
# 14798   9999107      2  2.000000
#
#                                                    title  ratings  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1                                          Yellow Crocus    17787
# 2                       Old Habits (Wicked Lovely, #2.6)     1628
# 3           Philosophy of Law: A Very Short Introduction      187
# 4                              Pollyanna (Pollyanna, #1)    58040
# ...                                                  ...      ...
# 14794                               The Boys from Brazil    25833
# 14795                                  The Bhagavad Gita    33855
# 14796                               Truly, Madly, Deeply     1268
# 14797                             The Woman in the Dunes    11841
# 14798                               The American Heiress    24522
#
#                                                      url  \
# 0      https://www.goodreads.com/book/show/1.Harry_Po...
# 1      https://www.goodreads.com/book/show/10000191-y...
# 2      https://www.goodreads.com/book/show/10000600-o...
# 3      https://www.goodreads.com/book/show/100020.Phi...
# 4      https://www.goodreads.com/book/show/1000751.Po...
# ...                                                  ...
# 14794  https://www.goodreads.com/book/show/99894.The_...
# 14795  https://www.goodreads.com/book/show/99944.The_...
# 14796  https://www.goodreads.com/book/show/9996645-tr...
# 14797  https://www.goodreads.com/book/show/9998.The_W...
# 14798  https://www.goodreads.com/book/show/9999107-th...
#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1361039191m...
# 1      https://s.gr-assets.com/assets/nophoto/book/11...
# 2      https://images.gr-assets.com/books/1327881013m...
# 3      https://s.gr-assets.com/assets/nophoto/book/11...
# 4      https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                  ...
# 14794  https://images.gr-assets.com/books/1328882615m...
# 14795  https://images.gr-assets.com/books/1383059639m...
# 14796  https://images.gr-assets.com/books/1293090850m...
# 14797  https://images.gr-assets.com/books/1361254930m...
# 14798  https://images.gr-assets.com/books/1307342832m...
#
#                                           modified_title  adjusted_count  \
# 0      harry potter and the halfblood prince harry po...        0.000071
# 1                                          yellow crocus        0.000056
# 2                            old habits wicked lovely 26        0.000614
# 3            philosophy of law a very short introduction        0.005348
# 4                                  pollyanna pollyanna 1        0.000017
# ...                                                  ...             ...
# 14794                               the boys from brazil        0.000039
# 14795                                  the bhagavad gita        0.000030
# 14796                                 truly madly deeply        0.003155
# 14797                             the woman in the dunes        0.000084
# 14798                               the american heiress        0.000163
#
#           score
# 0      0.000289
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# ...         ...
# 14794  0.000000
# 14795  0.000148
# 14796  0.000000
# 14797  0.000000
# 14798  0.000326
#
# [14758 rows x 10 columns]

# %%
#take out books we have read
my_books["mod_title"] = my_books["Title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower()

# %%
#remove if we already read it
# book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

# %%
book_recs = book_recs[book_recs["mean"] >=3]

# %%
book_recs = book_recs[book_recs["count"]>2]

# %%
top_recs = book_recs.sort_values("mean", ascending=False)

# %%
top_recs
# Out:
#         book_id  count      mean  \
# 747      114345      3  5.000000
# 13853   8306857      3  5.000000
# 11468      5093      3  4.333333
# 14216   8949352      3  4.333333
# 9229   30253864      3  4.333333
# ...         ...    ...       ...
# 5357   20727654      4  3.000000
# 5734   21853621     14  3.000000
# 8075   26245850      3  3.000000
# 7224     248483      3  3.000000
# 14778     99561      9  3.000000
#
#                                                    title  ratings  \
# 747     The Little House Collection (Little House, #1-9)   125070
# 13853                          Divergent (Divergent, #1)   213680
# 11468                                   Song of Susannah    87313
# 14216                                         Night Road    59265
# 9229   Talking as Fast as I Can: From Gilmore Girls t...    35052
# ...                                                  ...      ...
# 5357   The Paper Magician (The Paper Magician Trilogy...    26937
# 5734                                     The Nightingale   271556
# 8075                                     Before the Fall    54557
# 7224                         Austenland (Austenland, #1)    66992
# 14778                                 Looking for Alaska   804587
#
#                                                      url  \
# 747    https://www.goodreads.com/book/show/114345.The...
# 13853  https://www.goodreads.com/book/show/8306857-di...
# 11468  https://www.goodreads.com/book/show/5093.Song_...
# 14216  https://www.goodreads.com/book/show/8949352-ni...
# 9229   https://www.goodreads.com/book/show/30253864-t...
# ...                                                  ...
# 5357   https://www.goodreads.com/book/show/20727654-t...
# 5734   https://www.goodreads.com/book/show/21853621-t...
# 8075   https://www.goodreads.com/book/show/26245850-b...
# 7224   https://www.goodreads.com/book/show/248483.Aus...
# 14778  https://www.goodreads.com/book/show/99561.Look...
#
#                                              cover_image  \
# 747    https://s.gr-assets.com/assets/nophoto/book/11...
# 13853  https://images.gr-assets.com/books/1327873996m...
# 11468  https://images.gr-assets.com/books/1372296326m...
# 14216  https://images.gr-assets.com/books/1282369257m...
# 9229   https://images.gr-assets.com/books/1492797634m...
# ...                                                  ...
# 5357   https://images.gr-assets.com/books/1405618531m...
# 5734   https://images.gr-assets.com/books/1451446316m...
# 8075   https://images.gr-assets.com/books/1462515889m...
# 7224   https://s.gr-assets.com/assets/nophoto/book/11...
# 14778  https://images.gr-assets.com/books/1394798630m...
#
#                                           modified_title  adjusted_count  \
# 747          the little house collection little house 19        0.000072
# 13853                              divergent divergent 1        0.000042
# 11468                                   song of susannah        0.000103
# 14216                                         night road        0.000152
# 9229   talking as fast as i can from gilmore girls to...        0.000257
# ...                                                  ...             ...
# 5357     the paper magician the paper magician trilogy 1        0.000594
# 5734                                     the nightingale        0.000722
# 8075                                     before the fall        0.000165
# 7224                             austenland austenland 1        0.000134
# 14778                                 looking for alaska        0.000101
#
#           score
# 747    0.000360
# 13853  0.000211
# 11468  0.000447
# 14216  0.000658
# 9229   0.001113
# ...         ...
# 5357   0.001782
# 5734   0.002165
# 8075   0.000495
# 7224   0.000403
# 14778  0.000302
#
# [79 rows x 10 columns]

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_87ccd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87ccd_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_87ccd_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_87ccd_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_87ccd_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_87ccd_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_87ccd_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_87ccd_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_87ccd_level0_col7" class="col_heading level0 col7" >modified_title</th>
#       <th id="T_87ccd_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_87ccd_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87ccd_level0_row0" class="row_heading level0 row0" >747</th>
#       <td id="T_87ccd_row0_col0" class="data row0 col0" >114345</td>
#       <td id="T_87ccd_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_87ccd_row0_col2" class="data row0 col2" >5.000000</td>
#       <td id="T_87ccd_row0_col3" class="data row0 col3" >The Little House Collection (Little House, #1-9)</td>
#       <td id="T_87ccd_row0_col4" class="data row0 col4" >125070</td>
#       <td id="T_87ccd_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/114345.The_Little_House_Collection">Goodreads</a></td>
#       <td id="T_87ccd_row0_col6" class="data row0 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_87ccd_row0_col7" class="data row0 col7" >the little house collection little house 19</td>
#       <td id="T_87ccd_row0_col8" class="data row0 col8" >0.000072</td>
#       <td id="T_87ccd_row0_col9" class="data row0 col9" >0.000360</td>
#     </tr>
#     <tr>
#       <th id="T_87ccd_level0_row1" class="row_heading level0 row1" >13853</th>
#       <td id="T_87ccd_row1_col0" class="data row1 col0" >8306857</td>
#       <td id="T_87ccd_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_87ccd_row1_col2" class="data row1 col2" >5.000000</td>
#       <td id="T_87ccd_row1_col3" class="data row1 col3" >Divergent (Divergent, #1)</td>
#       <td id="T_87ccd_row1_col4" class="data row1 col4" >213680</td>
#       <td id="T_87ccd_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/8306857-divergent">Goodreads</a></td>
#       <td id="T_87ccd_row1_col6" class="data row1 col6" ><a href="https://images.gr-assets.com/books/1327873996m/8306857.jpg"><img src="https://images.gr-assets.com/books/1327873996m/8306857.jpg" width=50></img></a></td>
#       <td id="T_87ccd_row1_col7" class="data row1 col7" >divergent divergent 1</td>
#       <td id="T_87ccd_row1_col8" class="data row1 col8" >0.000042</td>
#       <td id="T_87ccd_row1_col9" class="data row1 col9" >0.000211</td>
#     </tr>
#     <tr>
#       <th id="T_87ccd_level0_row2" class="row_heading level0 row2" >11468</th>
#       <td id="T_87ccd_row2_col0" class="data row2 col0" >5093</td>
#       <td id="T_87ccd_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_87ccd_row2_col2" class="data row2 col2" >4.333333</td>
#       <td id="T_87ccd_row2_col3" class="data row2 col3" >Song of Susannah</td>
#       <td id="T_87ccd_row2_col4" class="data row2 col4" >87313</td>
#       <td id="T_87ccd_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/5093.Song_of_Susannah">Goodreads</a></td>
#       <td id="T_87ccd_row2_col6" class="data row2 col6" ><a href="https://images.gr-assets.com/books/1372296326m/5093.jpg"><img src="https://images.gr-assets.com/books/1372296326m/5093.jpg" width=50></img></a></td>
#       <td id="T_87ccd_row2_col7" class="data row2 col7" >song of susannah</td>
#       <td id="T_87ccd_row2_col8" class="data row2 col8" >0.000103</td>
#       <td id="T_87ccd_row2_col9" class="data row2 col9" >0.000447</td>
#     </tr>
#     <tr>
#       <th id="T_87ccd_level0_row3" class="row_heading level0 row3" >14216</th>
#       <td id="T_87ccd_row3_col0" class="data row3 col0" >8949352</td>
#       <td id="T_87ccd_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_87ccd_row3_col2" class="data row3 col2" >4.333333</td>
#       <td id="T_87ccd_row3_col3" class="data row3 col3" >Night Road</td>
#       <td id="T_87ccd_row3_col4" class="data row3 col4" >59265</td>
#       <td id="T_87ccd_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/8949352-night-road">Goodreads</a></td>
#       <td id="T_87ccd_row3_col6" class="data row3 col6" ><a href="https://images.gr-assets.com/books/1282369257m/8949352.jpg"><img src="https://images.gr-assets.com/books/1282369257m/8949352.jpg" width=50></img></a></td>
#       <td id="T_87ccd_row3_col7" class="data row3 col7" >night road</td>
#       <td id="T_87ccd_row3_col8" class="data row3 col8" >0.000152</td>
#       <td id="T_87ccd_row3_col9" class="data row3 col9" >0.000658</td>
#     </tr>
#     <tr>
#       <th id="T_87ccd_level0_row4" class="row_heading level0 row4" >9229</th>
#       <td id="T_87ccd_row4_col0" class="data row4 col0" >30253864</td>
#       <td id="T_87ccd_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_87ccd_row4_col2" class="data row4 col2" >4.333333</td>
#       <td id="T_87ccd_row4_col3" class="data row4 col3" >Talking as Fast as I Can: From Gilmore Girls to Gilmore Girls, and Everything in Between</td>
#       <td id="T_87ccd_row4_col4" class="data row4 col4" >35052</td>
#       <td id="T_87ccd_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/30253864-talking-as-fast-as-i-can">Goodreads</a></td>
#       <td id="T_87ccd_row4_col6" class="data row4 col6" ><a href="https://images.gr-assets.com/books/1492797634m/30253864.jpg"><img src="https://images.gr-assets.com/books/1492797634m/30253864.jpg" width=50></img></a></td>
#       <td id="T_87ccd_row4_col7" class="data row4 col7" >talking as fast as i can from gilmore girls to gilmore girls and everything in between</td>
#       <td id="T_87ccd_row4_col8" class="data row4 col8" >0.000257</td>
#       <td id="T_87ccd_row4_col9" class="data row4 col9" >0.001113</td>
#     </tr>
#     <tr>
#       <th id="T_87ccd_level0_row5" class="row_heading level0 row5" >1689</th>
#       <td id="T_87ccd_row5_col0" class="data row5 col0" >132541</td>
#       <td id="T_87ccd_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_87ccd_row5_col2" class="data row5 col2" >4.333333</td>
#       <td id="T_87ccd_row5_col3" class="data row5 col3" >The Secret of Platform 13</td>
#       <td id="T_87ccd_row5_col4" class="data row5 col4" >9467</td>
#       <td id="T_87ccd_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/132541.The_Secret_of_Platform_13">Goodreads</a></td>
#       <td id="T_87ccd_row5_col6" class="data row5 col6" ><a href="https://images.gr-assets.com/books/1443418592m/132541.jpg"><img src="https://images.gr-assets.com/books/1443418592m/132541.jpg" width=50></img></a></td>
#       <td id="T_87ccd_row5_col7" class="data row5 col7" >the secret of platform 13</td>
#       <td id="T_87ccd_row5_col8" class="data row5 col8" >0.000951</td>
#       <td id="T_87ccd_row5_col9" class="data row5 col9" >0.004120</td>
#     </tr>
#     <tr>
#       <th id="T_87ccd_level0_row6" class="row_heading level0 row6" >8406</th>
#       <td id="T_87ccd_row6_col0" class="data row6 col0" >2767052</td>
#       <td id="T_87ccd_row6_col1" class="data row6 col1" >14</td>
#       <td id="T_87ccd_row6_col2" class="data row6 col2" >4.285714</td>
#       <td id="T_87ccd_row6_col3" class="data row6 col3" >The Hunger Games (The Hunger Games, #1)</td>
#       <td id="T_87ccd_row6_col4"
