# %% [markdown]
# # Collaborative Filtering
#
# Using goodreads book list exported from my personal goodreads account. (goodread_library_export)

# %%
import pandas as pd
#only care about Book_Id, User_Id, and My_Rating
#goodreads_library_export is my export of data
my_books = pd.read_csv("data/goodreads_library_export.csv", skiprows = 1)

#filter for only Exclusive Shelf == read
my_books.columns = my_books.columns.str.replace(' ', '_')
my_books = my_books[my_books['Exclusive_Shelf'] == 'read']

my_books
# Out:
#       Book_Id  User_Id                                              Title  \
# 0     7896527       -1              Throne of Glass (Throne of Glass, #1)
# 1    35504431       -1                           Turtles All the Way Down
# 2    18774964       -1                                   A Man Called Ove
# 3    50659467       -1  A Court of Thorns and Roses (A Court of Thorns...
# 4    17788401       -1                                          Ugly Love
# ..        ...      ...                                                ...
# 206  39122774       -1  Children of Virtue and Vengeance (Legacy of Or...
# 224  40597810       -1                              Daisy Jones & The Six
# 234  34313931       -1                                  A Woman Is No Man
# 236  32051912       -1                                  The Alice Network
# 237  15796700       -1                                         Americanah
#
#                        Author                 Author_l-f Additional_Authors  \
# 0               Sarah J. Maas             Maas, Sarah J.                NaN
# 1                  John Green                Green, John                NaN
# 2             Fredrik Backman           Backman, Fredrik       Henning Koch
# 3               Sarah J. Maas             Maas, Sarah J.                NaN
# 4              Colleen Hoover            Hoover, Colleen                NaN
# ..                        ...                        ...                ...
# 206              Tomi Adeyemi              Adeyemi, Tomi                NaN
# 224       Taylor Jenkins Reid       Reid, Taylor Jenkins                NaN
# 234                  Etaf Rum                  Rum, Etaf                NaN
# 236                Kate Quinn                Quinn, Kate                NaN
# 237  Chimamanda Ngozi Adichie  Adichie, Chimamanda Ngozi        Jashar Awan
#
#            ISBN        ISBN13  My_Rating  Average_Rating  ...   Date_Read  \
# 0           NaN           NaN          4            4.18  ...         NaN
# 1    0525555366  9.780526e+12          4            3.88  ...         NaN
# 2    1476738017  9.781477e+12          3            4.38  ...         NaN
# 3    1635575567  9.781636e+12          4            4.18  ...         NaN
# 4           NaN           NaN          3            4.03  ...         NaN
# ..          ...           ...        ...             ...  ...         ...
# 206  1250170990  9.781250e+12          5            3.89  ...  2021/01/11
# 224  1524798622  9.781525e+12          5            4.20  ...  2020/07/13
# 234  0062699768  9.780063e+12          5            4.26  ...  2020/06/24
# 236         NaN           NaN          5            4.32  ...  2020/05/01
# 237         NaN           NaN          5            4.32  ...  2020/01/01
#
#      Date_Added  Bookshelves  Bookshelves_with_positions  Exclusive_Shelf  \
# 0    2022/09/08          NaN                         NaN             read
# 1    2022/07/18          NaN                         NaN             read
# 2    2019/10/16          NaN                         NaN             read
# 3    2022/08/12          NaN                         NaN             read
# 4    2022/07/22          NaN                         NaN             read
# ..          ...          ...                         ...              ...
# 206  2020/12/22          NaN                         NaN             read
# 224  2020/07/07          NaN                         NaN             read
# 234  2020/06/21          NaN                         NaN             read
# 236  2020/05/29          NaN                         NaN             read
# 237  2020/05/18          NaN                         NaN             read
#
#     My_Review Spoiler Private_Notes Read_Count Owned_Copies
# 0         NaN     NaN           NaN          1            0
# 1         NaN     NaN           NaN          1            0
# 2         NaN     NaN           NaN          1            0
# 3         NaN     NaN           NaN          1            0
# 4         NaN     NaN           NaN          1            0
# ..        ...     ...           ...        ...          ...
# 206       NaN     NaN           NaN          1            0
# 224       NaN     NaN           NaN          1            0
# 234       NaN     NaN           NaN          1            0
# 236       NaN     NaN           NaN          1            0
# 237       NaN     NaN           NaN          1            0
#
# [136 rows x 25 columns]

# %%
my_books['Book_Id'] = my_books['Book_Id'].astype(str)

# %%
#load in mapping file to link data
csv_book_mapping = {}

with open("data/book_id_map.csv", "r") as f:
    while True: 
        line = f.readline()
        if not line: 
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
#set of books with all unique books we have read
book_set = set(my_books["Book_Id"])

# %%
#looking at users that overlap with our books, 
#keys are user_ids and values are num of times user has read a book that we have in our list too

overlap_users = {}

with open("data/goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        book_id = csv_book_mapping.get(csv_id)
        
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 532737

# %%
#filter for people who have at least 20% books in common with us
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/5])

# %%
len(filtered_overlap_users)
# Out:
# 70

# %%
#add the filtered overlap users interactions into a list to look at
interactions_list = []

with open("data/goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

# %%
len(interactions_list)
# Out:
# 1472254

# %%
interactions_list[0] #user_id, book_id, rating
# Out:
# ['2794', '682745', '5']

# %%
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])
interactions
# Out:
#         user_id   book_id rating
# 0          2794    682745      5
# 1          2794     11466      5
# 2          2794     50275      0
# 3          2794     79090      0
# 4          2794      4980      0
# ...         ...       ...    ...
# 1472249  439355  33574122      0
# 1472250  439355  32446437      0
# 1472251  439355  35906271      0
# 1472252  439355    760309      0
# 1472253  439355    520975      0
#
# [1472254 rows x 3 columns]

# %%
#add my ratings to interactions df 
# rename Book_Id, User_Id, and My_Rating to match interactions col names
my_books = my_books.rename(columns={
    "User_Id": "user_id",
    "Book_Id": "book_id",
    "My_Rating": "rating"
})

interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])
interactions
# Out:
#         user_id   book_id rating
# 0            -1   7896527      4
# 1            -1  35504431      4
# 2            -1  18774964      3
# 3            -1  50659467      4
# 4            -1  17788401      3
# ...         ...       ...    ...
# 1472249  439355  33574122      0
# 1472250  439355  32446437      0
# 1472251  439355  35906271      0
# 1472252  439355    760309      0
# 1472253  439355    520975      0
#
# [1472390 rows x 3 columns]

# %%
#make sure everything is in correct form
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
#build a collaborative filtering matrix
#row is different user
#col is different book
#cell is rating

# %%
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes

# %%
len(interactions["user_index"].unique())
# Out:
# 71

# %%
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
len(interactions["book_index"].unique())
# Out:
# 466993

# %%
#sparse matrix
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
ratings_mat_coo
# Out:
# <71x466993 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1472390 stored elements in COOrdinate format>

# %%
ratings_mat_coo.shape
# Out:
# (71, 466993)

# %%
ratings_mat = ratings_mat_coo.tocsr()

# %%
interactions[interactions["user_id"] == "-1"]
# Out:
#     user_id   book_id  rating  user_index  book_index
# 0        -1   7896527       4           0      432192
# 1        -1  35504431       4           0      352429
# 2        -1  18774964       3           0      153833
# 3        -1  50659467       4           0      377721
# 4        -1  17788401       3           0      122501
# ..      ...       ...     ...         ...         ...
# 206      -1  39122774       5           0      361072
# 224      -1  40597810       5           0      363516
# 234      -1  34313931       5           0      344422
# 236      -1  32051912       5           0      327516
# 237      -1  15796700       5           0       82163
#
# [136 rows x 5 columns]

# %%
my_index = 0

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
similarity[2]
# Out:
# 0.0339632314336798

# %%
#take the top 15 users who are similar
import numpy as np
indices = np.argpartition(similarity, -15)[-15:]

# %%
indices
# Out:
# array([36, 48, 51,  2, 34, 61, 27, 38, 19, 17, 57,  6,  4, 56,  0])

# %%
similar_users = interactions[interactions["user_index"].isin(indices)].copy()

# %%
len(similar_users)
# Out:
# 68703

# %%
similar_users = similar_users[similar_users["user_id"]!="-1"]

# %%
len(similar_users)
# Out:
# 68567

# %%
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])

# %%
book_recs
# Out:
#           count      mean
# book_id
# 1             9  4.111111
# 1000012       1  0.000000
# 10000191      2  1.500000
# 10000269      2  0.000000
# 100003        1  0.000000
# ...         ...       ...
# 9998705       1  0.000000
# 9998825       1  0.000000
# 9999033       1  0.000000
# 9999107       5  0.000000
# 9999795       3  0.000000
#
# [40492 rows x 2 columns]

# %%
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 8554      11961    562660       3           4      385099
# 8555      11961   9681098       4           4      462074
# 8556      11961      5043       5           4      377455
# 8557      11961       930       5           4      455536
# 8558      11961      4989       5           4      376811
# ...         ...       ...     ...         ...         ...
# 1420113  430359  35604204       0          57      352957
# 1420114  430359  33515066       0          57      338435
# 1420115  430359  31737890       2          57      325148
# 1420116  430359  34723185       0          57      347467
# 1420117  430359  35430572       0          57      351968
#
# [68567 rows x 5 columns]

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#         book_id  count      mean  \
# 0             1      9  4.111111
# 1       1000012      1  0.000000
# 2      10000191      2  1.500000
# 3      10000269      2  0.000000
# 4        100003      1  0.000000
# ...         ...    ...       ...
# 39869   9998705      1  0.000000
# 39870   9998825      1  0.000000
# 39871   9999033      1  0.000000
# 39872   9999107      5  0.000000
# 39873   9999795      3  0.000000
#
#                                                    title  ratings  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1                                        A Wild Yearning      298
# 2                                          Yellow Crocus    17787
# 3                                                   Prey     5976
# 4      Stephen Hawking's Life Works: The Cambridge Le...       51
# ...                                                  ...      ...
# 39869          Flash and Bones (Temperance Brennan, #14)    14249
# 39870               Northwest Angle (Cork O'Connor, #11)     3357
# 39871  Wear This, Toss That!: Hundreds of Fashion and...      166
# 39872                               The American Heiress    24522
# 39873            Venom (Secrets of the Eternal Rose, #1)     4251
#
#                                                      url  \
# 0      https://www.goodreads.com/book/show/1.Harry_Po...
# 1      https://www.goodreads.com/book/show/1000012.A_...
# 2      https://www.goodreads.com/book/show/10000191-y...
# 3      https://www.goodreads.com/book/show/10000269-prey
# 4      https://www.goodreads.com/book/show/100003.Ste...
# ...                                                  ...
# 39869  https://www.goodreads.com/book/show/9998705-fl...
# 39870  https://www.goodreads.com/book/show/9998825-no...
# 39871  https://www.goodreads.com/book/show/9999033-we...
# 39872  https://www.goodreads.com/book/show/9999107-th...
# 39873  https://www.goodreads.com/book/show/9999795-venom
#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1361039191m...
# 1      https://s.gr-assets.com/assets/nophoto/book/11...
# 2      https://s.gr-assets.com/assets/nophoto/book/11...
# 3      https://images.gr-assets.com/books/1333576631m...
# 4      https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                  ...
# 39869  https://images.gr-assets.com/books/1306253347m...
# 39870  https://s.gr-assets.com/assets/nophoto/book/11...
# 39871  https://s.gr-assets.com/assets/nophoto/book/11...
# 39872  https://images.gr-assets.com/books/1307342832m...
# 39873  https://images.gr-assets.com/books/1331321794m...
#
#                                           modified_title
# 0      harry potter and the halfblood prince harry po...
# 1                                        a wild yearning
# 2                                          yellow crocus
# 3                                                   prey
# 4      stephen hawkings life works the cambridge lect...
# ...                                                  ...
# 39869              flash and bones temperance brennan 14
# 39870                    northwest angle cork oconnor 11
# 39871  wear this toss that hundreds of fashion and be...
# 39872                               the american heiress
# 39873                venom secrets of the eternal rose 1
#
# [39874 rows x 8 columns]

# %%
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"])

# %%
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"]

# %%
#take out books we have read
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

# %%
book_recs
# Out:
#         book_id  count      mean  \
# 0             1      9  4.111111
# 1       1000012      1  0.000000
# 2      10000191      2  1.500000
# 3      10000269      2  0.000000
# 4        100003      1  0.000000
# ...         ...    ...       ...
# 39869   9998705      1  0.000000
# 39870   9998825      1  0.000000
# 39871   9999033      1  0.000000
# 39872   9999107      5  0.000000
# 39873   9999795      3  0.000000
#
#                                                    title  ratings  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1                                        A Wild Yearning      298
# 2                                          Yellow Crocus    17787
# 3                                                   Prey     5976
# 4      Stephen Hawking's Life Works: The Cambridge Le...       51
# ...                                                  ...      ...
# 39869          Flash and Bones (Temperance Brennan, #14)    14249
# 39870               Northwest Angle (Cork O'Connor, #11)     3357
# 39871  Wear This, Toss That!: Hundreds of Fashion and...      166
# 39872                               The American Heiress    24522
# 39873            Venom (Secrets of the Eternal Rose, #1)     4251
#
#                                                      url  \
# 0      https://www.goodreads.com/book/show/1.Harry_Po...
# 1      https://www.goodreads.com/book/show/1000012.A_...
# 2      https://www.goodreads.com/book/show/10000191-y...
# 3      https://www.goodreads.com/book/show/10000269-prey
# 4      https://www.goodreads.com/book/show/100003.Ste...
# ...                                                  ...
# 39869  https://www.goodreads.com/book/show/9998705-fl...
# 39870  https://www.goodreads.com/book/show/9998825-no...
# 39871  https://www.goodreads.com/book/show/9999033-we...
# 39872  https://www.goodreads.com/book/show/9999107-th...
# 39873  https://www.goodreads.com/book/show/9999795-venom
#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1361039191m...
# 1      https://s.gr-assets.com/assets/nophoto/book/11...
# 2      https://s.gr-assets.com/assets/nophoto/book/11...
# 3      https://images.gr-assets.com/books/1333576631m...
# 4      https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                  ...
# 39869  https://images.gr-assets.com/books/1306253347m...
# 39870  https://s.gr-assets.com/assets/nophoto/book/11...
# 39871  https://s.gr-assets.com/assets/nophoto/book/11...
# 39872  https://images.gr-assets.com/books/1307342832m...
# 39873  https://images.gr-assets.com/books/1331321794m...
#
#                                           modified_title  adjusted_count  \
# 0      harry potter and the halfblood prince harry po...        0.000047
# 1                                        a wild yearning        0.003356
# 2                                          yellow crocus        0.000225
# 3                                                   prey        0.000669
# 4      stephen hawkings life works the cambridge lect...        0.019608
# ...                                                  ...             ...
# 39869              flash and bones temperance brennan 14        0.000070
# 39870                    northwest angle cork oconnor 11        0.000298
# 39871  wear this toss that hundreds of fashion and be...        0.006024
# 39872                               the american heiress        0.001019
# 39873                venom secrets of the eternal rose 1        0.002117
#
#           score
# 0      0.000194
# 1      0.000000
# 2      0.000337
# 3      0.000000
# 4      0.000000
# ...         ...
# 39869  0.000000
# 39870  0.000000
# 39871  0.000000
# 39872  0.000000
# 39873  0.000000
#
# [39831 rows x 10 columns]

# %%
#take out books we have read
my_books["mod_title"] = my_books["Title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower()

# %%
#remove if we already read it
# book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

# %%
book_recs = book_recs[book_recs["mean"] >=3]

# %%
book_recs = book_recs[book_recs["count"]>2]

# %%
top_recs = book_recs.sort_values("mean", ascending=False)

# %%
top_recs
# Out:
#         book_id  count      mean  \
# 16067         2     12  4.500000
# 37410   8306857      4  4.500000
# 2587   11870085     14  4.428571
# 31903         5     11  4.272727
# 6531     136251     13  4.230769
# 24959   2767052     14  4.142857
# 0             1      9  4.111111
# 5220   13335037     11  4.090909
# 33081         6     12  4.083333
# 19900  23164983      3  4.000000
#
#                                                    title  ratings  \
# 16067  Harry Potter and the Order of the Phoenix (Har...  1766895
# 37410                          Divergent (Divergent, #1)   213680
# 2587                              The Fault in Our Stars  2429317
# 31903  Harry Potter and the Prisoner of Azkaban (Harr...  1876252
# 6531   Harry Potter and the Deathly Hallows (Harry Po...  1784684
# 24959            The Hunger Games (The Hunger Games, #1)  4899965
# 0      Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 5220                           Divergent (Divergent, #1)  1962813
# 33081  Harry Potter and the Goblet of Fire (Harry Pot...  1792561
# 19900  Hollow City (Miss Peregrine’s Peculiar Childre...    77865
#
#                                                      url  \
# 16067  https://www.goodreads.com/book/show/2.Harry_Po...
# 37410  https://www.goodreads.com/book/show/8306857-di...
# 2587   https://www.goodreads.com/book/show/11870085-t...
# 31903  https://www.goodreads.com/book/show/5.Harry_Po...
# 6531   https://www.goodreads.com/book/show/136251.Har...
# 24959  https://www.goodreads.com/book/show/2767052-th...
# 0      https://www.goodreads.com/book/show/1.Harry_Po...
# 5220   https://www.goodreads.com/book/show/13335037-d...
# 33081  https://www.goodreads.com/book/show/6.Harry_Po...
# 19900  https://www.goodreads.com/book/show/23164983-h...
#
#                                              cover_image  \
# 16067  https://images.gr-assets.com/books/1507396732m...
# 37410  https://images.gr-assets.com/books/1327873996m...
# 2587   https://images.gr-assets.com/books/1360206420m...
# 31903  https://images.gr-assets.com/books/1499277281m...
# 6531   https://images.gr-assets.com/books/1474171184m...
# 24959  https://images.gr-assets.com/books/1447303603m...
# 0      https://images.gr-assets.com/books/1361039191m...
# 5220   https://images.gr-assets.com/books/1328559506m...
# 33081  https://images.gr-assets.com/books/1361482611m...
# 19900  https://images.gr-assets.com/books/1429175859m...
#
#                                           modified_title  adjusted_count  \
# 16067  harry potter and the order of the phoenix harr...        0.000081
# 37410                              divergent divergent 1        0.000075
# 2587                              the fault in our stars        0.000081
# 31903  harry potter and the prisoner of azkaban harry...        0.000064
# 6531   harry potter and the deathly hallows harry pot...        0.000095
# 24959                the hunger games the hunger games 1        0.000040
# 0      harry potter and the halfblood prince harry po...        0.000047
# 5220                               divergent divergent 1        0.000062
# 33081  harry potter and the goblet of fire harry pott...        0.000080
# 19900    hollow city miss peregrines peculiar children 2        0.000116
#
#           score
# 16067  0.000367
# 37410  0.000337
# 2587   0.000357
# 31903  0.000276
# 6531   0.000401
# 24959  0.000166
# 0      0.000194
# 5220   0.000252
# 33081  0.000328
# 19900  0.000462

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_945f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_945f2_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_945f2_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_945f2_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_945f2_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_945f2_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_945f2_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_945f2_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_945f2_level0_col7" class="col_heading level0 col7" >modified_title</th>
#       <th id="T_945f2_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_945f2_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_945f2_level0_row0" class="row_heading level0 row0" >16067</th>
#       <td id="T_945f2_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_945f2_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_945f2_row0_col2" class="data row0 col2" >4.500000</td>
#       <td id="T_945f2_row0_col3" class="data row0 col3" >Harry Potter and the Order of the Phoenix (Harry Potter, #5)</td>
#       <td id="T_945f2_row0_col4" class="data row0 col4" >1766895</td>
#       <td id="T_945f2_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2.Harry_Potter_and_the_Order_of_the_Phoenix">Goodreads</a></td>
#       <td id="T_945f2_row0_col6" class="data row0 col6" ><a href="https://images.gr-assets.com/books/1507396732m/2.jpg"><img src="https://images.gr-assets.com/books/1507396732m/2.jpg" width=50></img></a></td>
#       <td id="T_945f2_row0_col7" class="data row0 col7" >harry potter and the order of the phoenix harry potter 5</td>
#       <td id="T_945f2_row0_col8" class="data row0 col8" >0.000081</td>
#       <td id="T_945f2_row0_col9" class="data row0 col9" >0.000367</td>
#     </tr>
#     <tr>
#       <th id="T_945f2_level0_row1" class="row_heading level0 row1" >37410</th>
#       <td id="T_945f2_row1_col0" class="data row1 col0" >8306857</td>
#       <td id="T_945f2_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_945f2_row1_col2" class="data row1 col2" >4.500000</td>
#       <td id="T_945f2_row1_col3" class="data row1 col3" >Divergent (Divergent, #1)</td>
#       <td id="T_945f2_row1_col4" class="data row1 col4" >213680</td>
#       <td id="T_945f2_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/8306857-divergent">Goodreads</a></td>
#       <td id="T_945f2_row1_col6" class="data row1 col6" ><a href="https://images.gr-assets.com/books/1327873996m/8306857.jpg"><img src="https://images.gr-assets.com/books/1327873996m/8306857.jpg" width=50></img></a></td>
#       <td id="T_945f2_row1_col7" class="data row1 col7" >divergent divergent 1</td>
#       <td id="T_945f2_row1_col8" class="data row1 col8" >0.000075</td>
#       <td id="T_945f2_row1_col9" class="data row1 col9" >0.000337</td>
#     </tr>
#     <tr>
#       <th id="T_945f2_level0_row2" class="row_heading level0 row2" >2587</th>
#       <td id="T_945f2_row2_col0" class="data row2 col0" >11870085</td>
#       <td id="T_945f2_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_945f2_row2_col2" class="data row2 col2" >4.428571</td>
#       <td id="T_945f2_row2_col3" class="data row2 col3" >The Fault in Our Stars</td>
#       <td id="T_945f2_row2_col4" class="data row2 col4" >2429317</td>
#       <td id="T_945f2_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/11870085-the-fault-in-our-stars">Goodreads</a></td>
#       <td id="T_945f2_row2_col6" class="data row2 col6" ><a href="https://images.gr-assets.com/books/1360206420m/11870085.jpg"><img src="https://images.gr-assets.com/books/1360206420m/11870085.jpg" width=50></img></a></td>
#       <td id="T_945f2_row2_col7" class="data row2 col7" >the fault in our stars</td>
#       <td id="T_945f2_row2_col8" class="data row2 col8" >0.000081</td>
#       <td id="T_945f2_row2_col9" class="data row2 col9" >0.000357</td>
#     </tr>
#     <tr>
#       <th id="T_945f2_level0_row3" class="row_heading level0 row3" >31903</th>
#       <td id="T_945f2_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_945f2_row3_col1" class="data row3 col1" >11</td>
#       <td id="T_945f2_row3_col2" class="data row3 col2" >4.272727</td>
#       <td id="T_945f2_row3_col3" class="data row3 col3" >Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)</td>
#       <td id="T_945f2_row3_col4" class="data row3 col4" >1876252</td>
#       <td id="T_945f2_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/5.Harry_Potter_and_the_Prisoner_of_Azkaban">Goodreads</a></td>
#       <td id="T_945f2_row3_col6" class="data row3 col6" ><a href="https://images.gr-assets.com/books/1499277281m/5.jpg"><img src="https://images.gr-assets.com/books/1499277281m/5.jpg" width=50></img></a></td>
#       <td id="T_945f2_row3_col7" class="data row3 col7" >harry potter and the prisoner of azkaban harry potter 3</td>
#       <td id="T_945f2_row3_col8" class="data row3 col8" >0.000064</td>
#       <td id="T_945f2_row3_col9" class="data row3 col9" >0.000276</td>
#     </tr>
#     <tr>
#       <th id="T_945f2_level0_row4" class="row_heading level0 row4" >6531</th>
#       <td id="T_945f2_row4_col0" class="data row4 col0" >136251</td>
#       <td id="T_945f2_row4_col1" class="data row4 col1" >13</td>
#       <td id="T_945f2_row4_col2" class="data row4 col2" >4.230769</td>
#       <td id="T_945f2_row4_col3" class="data row4 col3" >Harry Potter and the Deathly Hallows (Harry Potter, #7)</td>
#       <td id="T_945f2_row4_col4" class="data row4 col4" >1784684</td>
#       <td id="T_945f2_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/136251.Harry_Potter_and_the_Deathly_Hallows">Goodreads</a></td>
#       <td id="T_945f2_row4_col6" class="data row4 col6" ><a href="https://images.gr-assets.com/books/1474171184m/136251.jpg"><img src="https://images.gr-assets.com/books/1474171184m/136251.jpg" width=50></img></a></td>
#       <td id="T_945f2_row4_col7" class="data row4 col7" >harry potter and the deathly hallows harry potter 7</td>
#       <td id="T_945f2_row4_col8" class="data row4 col8" >0.000095</td>
#       <td id="T_945f2_row4_col9" class="data row4 col9" >0.000401</td>
#     </tr>
#     <tr>
#       <th id="T_945f2_level0_row5" class="row_heading level0 row5" >24959</th>
#       <td id="T_945f2_row5_col0" class="data row5 col0" >2767052</td>
#       <td id="T_945f2_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_945f2_row5_col2" class="data row5 col2" >4.142857</td>
#       <td id="T_945f2_row5_col3" class="data row5 col3" >The Hunger Games (The Hunger Games, #1)</td>
#       <td id="T_945f2_row5_col4" class="data row5 col4" >4899965</td>
#       <td id="T_945f2_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2767052-the-hunger-games">Goodreads</a></td>
#       <td id="T_945f2_row5_col6" class="data row5 col6" ><a href="https://images.gr-assets.com/books/1447303603m/2767052.jpg"><img src="https://images.gr-assets.com/books/1447303603m/2767052.jpg" width=50></img></a></td>
#       <td id="T_945f2_row5_col7" class="data row5 col7" >the hunger games the hunger games 1</td>
#       <td id="T_945f2_row5_col8" class="data row5 col8" >0.000040</td>
#       <td id="T_945f2_row5_col9" class="data row5 col9" >0.000166</td>
#     </tr>
#     <tr>
#       <th id="T_945f2_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_945f2_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_945f2_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_945f2_row6_col2" class="data row6 col2" >4.111111</td>
#       <td id="T_945f2_row6_col3" class="data row6 col3" >Harry Potter and the Half
